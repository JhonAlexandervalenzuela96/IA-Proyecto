# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1CzLtOBdQmNARZQ35xPFjxDX0V7XKEqmj?usp=sharing)

# %% [markdown]
# # **Proyecto Entrega 2**

# %% [markdown]
# A continuacion para cumplir los requisitos exigidos se va a realizar la eliminacion de forma aleatoria en 3 columnas y se va a cambiar la informacion de  columnas a categoricas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/marialopez33/IA-Proyecto/main/data.csv")

# %%
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
num_filas = df["Bankrupt?"].size

# %%
num_col = df.iloc[0].size #Numero de columnas

# %%
print("Numero de filas: {0} - Numero de columnas {1}".format(num_filas,num_col))
# Out:
# Numero de filas: 6819 - Numero de columnas 96

# %%
df_info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
df_description = df.describe()
df_description
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %%
df.hist(figsize = (35,35), bins = 50)
plt.show()

# %%
j = 0
columns_df = df.columns
dict_columns = {}
for i in columns_df:
    df.rename(columns={i:j},inplace=True)
    dict_columns[j] = i
    j += 1
df
# Out:
#       0         1         2         3         4         5         6   \
# 0      1  0.370594  0.424389  0.405750  0.601457  0.601457  0.998969
# 1      1  0.464291  0.538214  0.516730  0.610235  0.610235  0.998946
# 2      1  0.426071  0.499019  0.472295  0.601450  0.601364  0.998857
# 3      1  0.399844  0.451265  0.457733  0.583541  0.583541  0.998700
# 4      1  0.465022  0.538432  0.522298  0.598783  0.598783  0.998973
# ...   ..       ...       ...       ...       ...       ...       ...
# 6814   0  0.493687  0.539468  0.543230  0.604455  0.604462  0.998992
# 6815   0  0.475162  0.538269  0.524172  0.598308  0.598308  0.998992
# 6816   0  0.472725  0.533744  0.520638  0.610444  0.610213  0.998984
# 6817   0  0.506264  0.559911  0.554045  0.607850  0.607850  0.999074
# 6818   0  0.493053  0.570105  0.549548  0.627409  0.627409  0.998080
#
#             7         8         9   ...        86        87        88  \
# ...

# %%
dict_columns
# Out:
# {0: 'Bankrupt?',
#  1: ' ROA(C) before interest and depreciation before interest',
#  2: ' ROA(A) before interest and % after tax',
#  3: ' ROA(B) before interest and depreciation after tax',
#  4: ' Operating Gross Margin',
#  5: ' Realized Sales Gross Margin',
#  6: ' Operating Profit Rate',
#  7: ' Pre-tax net Interest Rate',
#  8: ' After-tax net Interest Rate',
#  9: ' Non-industry income and expenditure/revenue',
#  10: ' Continuous interest rate (after tax)',
#  11: ' Operating Expense Rate',
#  12: ' Research and development expense rate',
#  13: ' Cash flow rate',
#  14: ' Interest-bearing debt interest rate',
#  15: ' Tax rate (A)',
#  16: ' Net Value Per Share (B)',
#  17: ' Net Value Per Share (A)',
#  18: ' Net Value Per Share (C)',
#  19: ' Persistent EPS in the Last Four Seasons',
#  20: ' Cash Flow Per Share',
#  21: ' Revenue Per Share (Yuan ¥)',
#  22: ' Operating Profit Per Share (Yuan ¥)',
#  23: ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %%
def column_to_discrete(column_df):
    for i in range(len(column_df)):
        if column_df[i]<=0.45:
            column_df.loc[i] = "Low"
        elif column_df[i] >= 0.55:
            column_df.loc[i] = "High"
        else:
            column_df.loc[i] = "Medium"

# %%
column_to_discrete(df[3])
column_to_discrete(df[21])
column_to_discrete(df[35])
column_to_discrete(df[5])
column_to_discrete(df[37])
column_to_discrete(df[75])
column_to_discrete(df[81])
column_to_discrete(df[65])
column_to_discrete(df[82])
column_to_discrete(df[56])
# Out:
# <ipython-input-12-6718aadd2671>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_df.loc[i] = "Low"
# <ipython-input-12-6718aadd2671>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_df.loc[i] = "High"
# <ipython-input-12-6718aadd2671>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_df.loc[i] = "Medium"

# %%
black_list = [0,3,21,35,5,37,75,81,65,82,56,94]

# %%
num = -1
i = 0
while True:
    num = np.random.randint(0,high=96)
    if num not in black_list:
        df.loc[200:700,num] = np.nan
        i += 1
    if i == 3:
        break

# %%
j = 0
columns_df = df.columns
for i in columns_df:
    df.rename(columns={i:dict_columns[i]},inplace=True)
    j += 1
df
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
list_na = df.columns[df.isna().any()].tolist()

# %%
list_na
# Out:
# [' ROA(A) before interest and % after tax',
#  ' Quick Assets/Total Assets',
#  ' Liability to Equity']

# %% [markdown]
# # **Exploracion de la informacion procesada**

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('always')
# %matplotlib inline

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# ...

# %% [markdown]
# # **Tamaño del dataset**

# %%
df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (6819, 96)

# %% [markdown]
# # **Valores nulos**

# %%
na_values = df.isna().sum()
na_values[na_values != 0]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#  ROA(A) before interest and % after tax    501
#  Quick Assets/Total Assets                 501
#  Liability to Equity                       501
# dtype: int64

# %% [markdown]
# # **Variable objetivo**

# %%
sns.histplot(df["Bankrupt?"]);
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # **Tipos de datos**

# %%
df.columns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6318 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   object
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   object
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %% [markdown]
# # **Inspeccionando data numérica**

# %%
df._get_numeric_data().describe().T
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                      count      mean  \
# Bankrupt?                                           6819.0  0.032263
#  ROA(C) before interest and depreciation before...  6819.0  0.505180
#  ROA(A) before interest and % after tax             6318.0  0.560019
#  Operating Gross Margin                             6819.0  0.607948
#  Operating Profit Rate                              6819.0  0.998755
# ...                                                    ...       ...
#  Liability to Equity                                6318.0  0.280338
# ...

# %% [markdown]
# # **Correlaciones**

# %%
correlation_matrix = df.corr()
d, ax = plt.subplots(figsize=(12,9))
sns.heatmap(correlation_matrix,vmax=8,square=True);
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-27-65b63cd5f2ef>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# # **Inspeccionando variables categóricas**

# %%
categorical_columns = [i for i in df.columns if not i in df._get_numeric_data()]
print(categorical_columns)
# Out:
# [' ROA(B) before interest and depreciation after tax', ' Realized Sales Gross Margin', ' Revenue Per Share (Yuan ¥)', ' Interest Expense Ratio', ' Debt ratio %', ' Current Assets/Total Assets', ' Working Capital/Equity', ' Cash Flow to Sales', ' Cash Flow to Liability', ' CFO to Assets']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for c in categorical_columns:
    print ("%10s"%c, np.unique(df[c].dropna()))
# Out:
#  ROA(B) before interest and depreciation after tax ['High' 'Low' 'Medium']
#  Realized Sales Gross Margin ['High' 'Low' 'Medium']
#  Revenue Per Share (Yuan ¥) ['High' 'Low' 'Medium']
#  Interest Expense Ratio ['High' 'Low' 'Medium']
#  Debt ratio % ['High' 'Low' 'Medium']
#  Current Assets/Total Assets ['High' 'Low' 'Medium']
#  Working Capital/Equity ['High' 'Low' 'Medium']
#  Cash Flow to Sales ['High' 'Low']
#  Cash Flow to Liability ['High' 'Low' 'Medium']
#  CFO to Assets ['High' 'Low' 'Medium']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for column in categorical_columns:
    print(df[column].value_counts())
# Out:
# High      3585
# Medium    2959
# Low        275
# Name:  ROA(B) before interest and depreciation after tax, dtype: int64
# High      6800
# Medium      13
# Low          6
# Name:  Realized Sales Gross Margin, dtype: int64
# Low       6807
# High        10
# Medium       2
# Name:  Revenue Per Share (Yuan ¥), dtype: int64
# High      6814
# Medium       4
# Low          1
# Name:  Interest Expense Ratio, dtype: int64
# Low       6817
# High         1
# Medium       1
# Name:  Debt ratio %, dtype: int64
# High      3011
# Low       2749
# Medium    1059
# Name:  Current Assets/Total Assets, dtype: int64
# High      6816
# Medium       2
# Low          1
# Name:  Working Capital/Equity, dtype: int64
# High    6818
# Low        1
# Name:  Cash Flow to Sales, dtype: int64
# Medium    6087
# Low        660
# High        72
# Name:  Cash Flow to Liability, dtype: int64
# High      5687
# Medium    1024
# Low        108
# Name:  CFO to Assets, dtype: int64
# ...

# %%
plt.figure(figsize=(20,8))
for i,c in enumerate(categorical_columns):
    plt.subplot(3,5,i+1)
    k=df[[c,"Bankrupt?"]].dropna()
    for v in df[c].dropna().unique():
        sns.histplot(k['Bankrupt?'][k[c]==v], label=v,kde=True, stat="density", linewidth=0);
        plt.title(c)
    plt.yticks([])
    plt.legend()
    plt.subplot(3,5,i+5)
    vc = k[c].value_counts()
    sns.barplot(x=vc.index, y = vc.values)
    plt.xticks(range(len(vc)), vc.index, rotation="vertical")
    plt.tight_layout()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# ...

# %% [markdown]
# # **Reparando la data faltante**

# %%
k = df.isna().sum()
k[k!=0]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#  ROA(A) before interest and % after tax    501
#  Quick Assets/Total Assets                 501
#  Liability to Equity                       501
# dtype: int64

# %%
list_na = df.columns[df.isna().any()].tolist()
list_na
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [' ROA(A) before interest and % after tax',
#  ' Quick Assets/Total Assets',
#  ' Liability to Equity']

# %%
for i in list_na:
    df[i].fillna(df[i].mean(),inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # **One hot encoding**

# %%
def to_onehot(x):
    values = np.unique(x)
    r = np.r_[[np.argwhere(i==values)[0][0] for i in x]]
    return np.eye(len(values))[r].astype(int)

def replace_column_with_onehot(df, col):
    assert sum(df[col].isna())==0, "column must have no NaN values"
    values = np.unique(df[col]
                      )
    k = to_onehot(df[col].values)
    r = pd.DataFrame(k, columns=["%s_%s"%(col, values[i]) for i in range(k.shape[1])], index=df.index).join(df)
    del(r[col])
    return r
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
list_cat = [i for i in df.columns if not i in df._get_numeric_data()]
list_cat
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [' ROA(B) before interest and depreciation after tax',
#  ' Realized Sales Gross Margin',
#  ' Revenue Per Share (Yuan ¥)',
#  ' Interest Expense Ratio',
#  ' Debt ratio %',
#  ' Current Assets/Total Assets',
#  ' Working Capital/Equity',
#  ' Cash Flow to Sales',
#  ' Cash Flow to Liability',
#  ' CFO to Assets']

# %%
print(len(list_cat))
# Out:
# 10
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for i in list_cat:
    df_aux = pd.get_dummies(df[i], prefix=i)
    df.drop(i,inplace=True,axis=1)
    df = df.join(df_aux)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax   Operating Gross Margin  \
# 0                                 0.424389                 0.601457
# 1                                 0.538214                 0.610235
# ...

# %%
[i for i in df.columns if not i in df._get_numeric_data()]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# []

# %%
df.to_csv('new_data.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# ...

# %%
from google.colab import files
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
files.download('new_data.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
